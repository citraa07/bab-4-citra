# %% [markdown]
# <a href="https://colab.research.google.com/github/citraa07/bab-4-citra/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("halo, Citra")
# Out:
# halo, Citra
